# %% [markdown]
# ### Simple CNN 1
# The code below is a simple implementation of cnn with the same basic architecture found in ALVINN

# %%
import matplotlib
# Remove padding around screen

from PIL import Image
from os import walk
from IPython.core.display import display, HTML
import matplotlib.pyplot as plt
import matplotlib.image as img
import tensorflow as tf
import numpy,keras,PIL,sys


sys.path.insert(0, "/home/jason/sproj/scripts/")
from train import DataLoader
import train

display(HTML("<style>"
    + "#notebook { padding-top:0px !important; } " 
    + ".container { width:100% !important; } "
    + ".end_space { min-height:0px !important; } "
    + "</style>"))
# Out:
# <style>#notebook { padding-top:0px !important; } .container { width:100% !important; } .end_space { min-height:0px !important; } </style>

# %%
filepath = "../datasets/car-data-3-4/"
dl = DataLoader(filepath,10000)

#filepath = "../datasets/track_sess_2-23/"
train_x, train_y = dl.load()

# %%
print(train_x.shape)
imgplot = plt.imshow(train_x[10])
# Out:
# (10001, 120, 160, 3)

# %%
import models

# Load callbacks
checkpointer = keras.callbacks.ModelCheckpoint(
    filepath='../outputs/track_cnnw3.h5',
    verbose=1,
    save_best_only=True)


# Get training image row, col, channels
img_sz = train_x.shape[1:]
model = models.get_nvidia_model(1)
#train_generator, validation_generator, n_train, n_val \
#    = train.make_generators(20000, limit=limit, batch_size=batch_size, aug_perc=aug_perc)

model.compile(optimizer='adam',
              loss='mean_absolute_error',
              metrics=['accuracy'])

model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ae459079a68f> in <module>()
#      11 img_sz = train_x.shape[1:]
#      12 model = models.get_nvidia_model(1)
# ---> 13 train_generator, validation_generator, n_train, n_val     = train.make_generators(inputs, limit=limit, batch_size=batch_size, aug_perc=aug_perc)
#      14
#      15 model.compile(optimizer='adam',
#
# NameError: name 'inputs' is not defined

# %%
model.fit(x=train_x,y=train_y,epochs=40,validation_split=0.2,callbacks=[checkpointer],batch_size=8)
# Out:
# Train on 8000 samples, validate on 2001 samples
# Epoch 1/40
# 8000/8000 [==============================] - 9s 1ms/step - loss: 8.1021 - acc: 0.0263 - val_loss: 7.4776 - val_acc: 0.0095
#
# Epoch 00001: val_loss improved from inf to 7.47756, saving model to ../outputs/track_cnnw3.h5
# Epoch 2/40
# 8000/8000 [==============================] - 8s 1ms/step - loss: 6.8068 - acc: 0.0405 - val_loss: 5.8402 - val_acc: 0.0535
#
# Epoch 00002: val_loss improved from 7.47756 to 5.84025, saving model to ../outputs/track_cnnw3.h5
# Epoch 3/40
# 8000/8000 [==============================] - 8s 1ms/step - loss: 5.8493 - acc: 0.0603 - val_loss: 5.5920 - val_acc: 0.0770
#
# Epoch 00003: val_loss improved from 5.84025 to 5.59205, saving model to ../outputs/track_cnnw3.h5
# Epoch 4/40
# 8000/8000 [==============================] - 8s 1ms/step - loss: 5.5139 - acc: 0.0704 - val_loss: 5.4654 - val_acc: 0.0780
#
# Epoch 00004: val_loss improved from 5.59205 to 5.46535, saving model to ../outputs/track_cnnw3.h5
# Epoch 5/40
# 8000/8000 [==============================] - 8s 1ms/step - loss: 5.3317 - acc: 0.0790 - val_loss: 5.0247 - val_acc: 0.0825
#
# Epoch 00005: val_loss improved from 5.46535 to 5.02472, saving model to ../outputs/track_cnnw3.h5
# Epoch 6/40
# 8000/8000 [==============================] - 8s 1ms/step - loss: 5.0507 - acc: 0.0890 - val_loss: 5.2044 - val_acc: 0.0700
#
# Epoch 00006: val_loss did not improve
# Epoch 7/40
# 8000/8000 [==============================] - 8s 1ms/step - loss: 4.9537 - acc: 0.0842 - val_loss: 4.9971 - val_acc: 0.0645
#
# Epoch 00007: val_loss improved from 5.02472 to 4.99714, saving model to ../outputs/track_cnnw3.h5
# Epoch 8/40
# 8000/8000 [==============================] - 8s 1ms/step - loss: 4.8590 - acc: 0.0921 - val_loss: 4.9906 - val_acc: 0.0680
#
# Epoch 00008: val_loss improved from 4.99714 to 4.99063, saving model to ../outputs/track_cnnw3.h5
# Epoch 9/40
# 8000/8000 [==============================] - 8s 1ms/step - loss: 4.8234 - acc: 0.0912 - val_loss: 5.1078 - val_acc: 0.0895
#
# Epoch 00009: val_loss did not improve
# Epoch 10/40
# 8000/8000 [==============================] - 8s 1ms/step - loss: 4.5346 - acc: 0.0932 - val_loss: 4.9987 - val_acc: 0.0815
#
# Epoch 00010: val_loss did not improve
# Epoch 11/40
# 8000/8000 [==============================] - 8s 1ms/step - loss: 7.8120 - acc: 0.1369 - val_loss: 8.4126 - val_acc: 0.1614
#
# Epoch 00011: val_loss did not improve
# Epoch 12/40
# 8000/8000 [==============================] - 8s 1ms/step - loss: 8.6930 - acc: 0.1705 - val_loss: 8.5387 - val_acc: 0.1679
#
# Epoch 00012: val_loss did not improve
# Epoch 13/40
# 8000/8000 [==============================] - 8s 1ms/step - loss: 8.6880 - acc: 0.1726 - val_loss: 8.5403 - val_acc: 0.1679
#
# Epoch 00013: val_loss did not improve
# Epoch 14/40
# 8000/8000 [==============================] - 8s 1ms/step - loss: 8.6856 - acc: 0.1726 - val_loss: 8.5443 - val_acc: 0.1679
#
# Epoch 00014: val_loss did not improve
# Epoch 15/40
# 8000/8000 [==============================] - 8s 1ms/step - loss: 8.6886 - acc: 0.1726 - val_loss: 8.5413 - val_acc: 0.1679
#
# Epoch 00015: val_loss did not improve
# Epoch 16/40
# 8000/8000 [==============================] - 8s 1ms/step - loss: 8.6908 - acc: 0.1726 - val_loss: 8.5479 - val_acc: 0.1679
#
# Epoch 00016: val_loss did not improve
# Epoch 17/40
# 8000/8000 [==============================] - 8s 1ms/step - loss: 8.6899 - acc: 0.1726 - val_loss: 8.5567 - val_acc: 0.1679
#
# Epoch 00017: val_loss did not improve
# Epoch 18/40
# 8000/8000 [==============================] - 8s 1ms/step - loss: 8.6908 - acc: 0.1714 - val_loss: 8.5421 - val_acc: 0.1679
#
# Epoch 00018: val_loss did not improve
# Epoch 19/40
# 8000/8000 [==============================] - 8s 1ms/step - loss: 8.6914 - acc: 0.1726 - val_loss: 8.5834 - val_acc: 0.1679
#
# Epoch 00019: val_loss did not improve
# Epoch 20/40
# 5240/8000 [==================>...........] - ETA: 2s - loss: 8.7549 - acc: 0.1746
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-8e0e15ffbf49> in <module>()
# ----> 1 model.fit(x=train_x,y=train_y,epochs=40,validation_split=0.2,callbacks=[checkpointer],batch_size=8)
#
# /usr/local/lib/python3.6/dist-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     961                               initial_epoch=initial_epoch,
#     962                               steps_per_epoch=steps_per_epoch,
# --> 963                               validation_steps=validation_steps)
#     964
#     965     def evaluate(self, x=None, y=None,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1710                               initial_epoch=initial_epoch,
#    1711                               steps_per_epoch=steps_per_epoch,
# -> 1712                               validation_steps=validation_steps)
#    1713
#    1714     def evaluate(self, x=None, y=None,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1233                         ins_batch[i] = ins_batch[i].toarray()
#    1234
# -> 1235                     outs = f(ins_batch)
#    1236                     if not isinstance(outs, list):
#    1237                         outs = [outs]
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2475                               **self.session_kwargs)
#    2476         return updated[:len(self.outputs)]
#    2477
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1311       # pylint: enable=protected-access
#    1312     else:
# -> 1313       feeds = dict((compat.as_bytes(t.name), v) for t, v in feed_dict.items())
#    1314       fetches = _name_list(fetch_list)
#    1315       targets = _name_list(target_list)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in <genexpr>(.0)
#    1311       # pylint: enable=protected-access
#    1312     else:
# -> 1313       feeds = dict((compat.as_bytes(t.name), v) for t, v in feed_dict.items())
#    1314       fetches = _name_list(fetch_list)
#    1315       targets = _name_list(target_list)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in name(self)
#     325     if not self._op.name:
#     326       raise ValueError("Operation was not named: %s" % self._op)
# --> 327     return "%s:%d" % (self._op.name, self._value_index)
#     328
#     329   @property
#
# KeyboardInterrupt:
